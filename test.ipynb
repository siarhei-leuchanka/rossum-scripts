# %%
# SL
import json
import pandas as pd
import ipywidgets as widgets
from IPython.display import display
import asyncio
import aiohttp

class Annotation():
    def __init__(self, metadata:json) -> None:
        self.metadata = metadata
        self.id = metadata.get("id", "na")
        self.queue = metadata.get("queue", "na").split("/")[-1]
        self.schema = metadata.get("schema", "na").split("/")[-1]

    def set_content(self, annotation:list) -> None:
        self.content_data = annotation
        
    def find_by_schema_id(self, content, schema_id: str):
        """
        Return all datapoints matching a schema id.
        :param content: annotation content tree 
        :param schema_id: f
        :return: the list of datapoints matching the schema ID
        """
        accumulator = []
        for node in content:
            if node["schema_id"] == schema_id:
                accumulator.append(node)
            elif "children" in node:
                accumulator.extend(self.find_by_schema_id(node["children"], schema_id))

        return accumulator
    
    def get_id_data(self, schema_id):
        return self.find_by_schema_id(self.content_data, schema_id)
    
    def get_positions(self, schema_id):
        datapoints = self.get_id_data(schema_id)
        positions = []
        for datapoint in datapoints:
            content = datapoint['content']
            if content['position']:
                positions.append(content['position'])
            else:
                positions.append(None)
        return positions



class AsyncRequestClient():    
    
    BASE_URL = "https://elis.rossum.ai/api" 
    HEADERS = {
        "Content-Type": "application/json",
    }
    
    def __init__(self, token, domain=None):
        self.token = token
        self.base_url = domain or AsyncRequestClient.BASE_URL    
        self.request_cache = {}

    def reset_inputs(self, token, domain):
        self.token = token
        self.base_url = domain


    async def _make_request(self, method, endpoint, headers=None, data=None, json=None, files=None, cache_on=True, ready_url=None):
        url = ready_url or  f"{self.base_url}/v1{endpoint}"
        headers = headers or AsyncRequestClient.HEADERS
        headers["Authorization"] = f"Bearer {self.token}"
        
        if self.request_cache.get(url, False) and cache_on:
            if self.request_cache[url]["json"] == json:
                print(f"Cached {url}")
                return self.request_cache[url]["response"]
        
        async with aiohttp.ClientSession() as session:
            try:
                async with session.request(method, url, headers=headers, data=data, json=json,) as response:
                    print(url, "  Request")
                    if response.status == 200:
                        self.request_cache[url] = {
                            "response": await response.json(),
                            "json": json                       
                                                }
                        return await response.json()
                    else:
                        print(response)
                        raise aiohttp.ClientResponseError
            except aiohttp.ClientResponseError as e:
                print("ClientResponseError occurred:", e)


    async def _get_annotation_content(self, annotation_id):
        endpoint = f"/annotations/{annotation_id}/content"
        response = await self._make_request("GET", endpoint, cache_on=True)        
        return response

    async def _search(self, params=None, next_page=None):        
        if next_page:
            response = await self._make_request("POST", self.endpoint, json=params, cache_on=True, ready_url=next_page)
        else: 
            self.endpoint = f"/annotations/search"         
            response = await self._make_request("POST", self.endpoint, json=params, cache_on=True)
                
        pagination = response["pagination"]
        next_page = pagination.get("next", False)                
        
        return next_page, response["results"]
    
    async def search_with_query(self, query:json ,allPages:bool = False)->dict:                
        annotation_library = {}        
        next, response  = await self._search(params=query)     
        
        for result in response:
            annotation_library[result["id"]] = Annotation(result)
        
        if allPages:
            while next:         
                next,response = await self._search(params=query, next_page=next)            
                for result in response:
                    annotation_library[result["id"]] = Annotation(result)
                                    
        return annotation_library

def form_dataset(obj:Annotation, key:str, field_id:str)->pd.DataFrame:
    temp_list = []
    datapoints = obj.find_by_schema_id(obj.content_data, field_id)
    if datapoints:
        for datapoint in datapoints:            
            content_value = datapoint["content"]["value"]
            temp_list.append({"IDs":key, field_id:content_value})
        temp_df = pd.DataFrame(temp_list)
        temp_df.set_index("IDs", inplace=True)
        return temp_df
    return pd.DataFrame() 

def show_results(field_ids, annotations_collection, base_url)-> display:    
    output = pd.DataFrame()
    for key, obj in annotations_collection.items():
        if len(field_ids) > 1:
            temp_merged_df = pd.DataFrame([{"IDs":key, "Address":f"{base_url}/{key}"}])
            temp_merged_df.set_index("IDs", inplace=True)            
            for field_id in field_ids:
                temp_merged_df = temp_merged_df.merge(form_dataset(obj,key,field_id), how='outer',left_index=True, right_index=True)
            output = pd.concat([output,temp_merged_df])
        else:            
            output = pd.concat([output,form_dataset(obj,key, field_ids[0])])
                        
    def make_clickable(url):
        return f'<a href="{url}" target="_blank">link</a>'
    
    styled_output = output.style.format({'Address': make_clickable})    
    display(styled_output)
    


# Function to create input widgets for a given set number
def create_input_widgets():      
    token_input = widgets.Textarea(value="", description=f"TOKEN:")
    url_input = widgets.Textarea(value="", description=f"Custom Domain:")    
    field_ids = widgets.Textarea(value="document_id", description = "Field ID to check")
    query = widgets.Textarea(
                    value= '{\n    "query": {\n        "$and": [\n            {\n                "queue": {\n                    "$in": [\n                        "https://elis.rossum.ai/api/v1/queues/XXXXXX",\n                        "https://elis.rossum.ai/api/v1/queues/XXXXXX",\n                        "https://elis.rossum.ai/api/v1/queues/XXXXXX"\n                    ]\n                }\n            },\n            {\n                "field.document_id.string": {\n                    "$emptyOrMissing": false\n                }\n            },\n            {\n                "status": {\n                    "$in": [\n                        "confirmed",\n                        "exported"\n                    ]\n                }\n            }\n        ]\n    }\n}',
                    description='Filter Query',
                    layout={'width': '80%', 'height': '500px'}  # Set width to 80% of the available space
                        )
    bool_toggle = widgets.ToggleButtons(
                    options=[True, False],
                    description='Load all pages of annotations:',                    
                    tooltips=['True', 'False'],
                    value=False # Default value                
                )
    
    options_with_labels = {'prod-eu': 'https://elis.rossum.ai', 'prod-jp': 'https://shared-jp.app.rossum.ai', 
                           'prod-eu2': f'.rossum.app', 'prod-us': 'https://us.app.rossum.ai'}
    dropdown = widgets.Dropdown(
                options=options_with_labels,
                description='Environment:'
                )

    return token_input, url_input, query, field_ids, bool_toggle, dropdown


async def process_annotations(client, token_input, url_input, query, field_ids, bool_toggle, dropdown):
    #query_string = query.value.replace("\n", "")
    #field_ids = field_ids.value.split(',')    

    if dropdown.label == "prod-eu2":
        url = f'https://{url_input.value}{dropdown.value}'
        client.reset_inputs(token_input, f'{url}/api')
    else:
        url = f'{dropdown.value}'
        client.reset_inputs(token_input, f'{url}/api')

    annotations_collection = await client.search_with_query(query, allPages=bool_toggle.value)

    # Create a list of coroutines for fetching annotation content
    annotation_tasks = [client._get_annotation_content(key) for key in annotations_collection.keys()]

    # Execute all annotation content fetching tasks concurrently
    annotation_contents = await asyncio.gather(*annotation_tasks)

    # Update annotation objects with fetched content
    for key, annotation_content in zip(annotations_collection.keys(), annotation_contents):
        obj = annotations_collection[key]
        content = annotation_content
        content= content["content"]
        obj.set_content(content)

    # show_results(field_ids, annotations_collection, base_url=f'{url}/document')
    return annotations_collection

# %%
# #Initialize client
client = AsyncRequestClient('', '')

# Initialize the set_widgets list
token_input, url_input, query, field_id, bool_toggle, dropdown = create_input_widgets()
display(dropdown, url_input, bool_toggle)
# Out:
# Dropdown(description='Environment:', options={'prod-eu': 'https://elis.rossum.ai', 'prod-jp': 'https://shared-…
# Textarea(value='', description='Custom Domain:')
# ToggleButtons(description='Load all pages of annotations:', index=1, options=(True, False), tooltips=('True', …

# %%
token_input = "abf6c9c6bcbb003039a77ab681b4d1a008c85ec6"
query = {
    "query": {
        "$and": [
            # {
            #     "queue": {
            #         "$in": [
            #             "https://elis.rossum.ai/api/v1/queues/XXXXXX",
            #             "https://elis.rossum.ai/api/v1/queues/XXXXXX",
            #             "https://elis.rossum.ai/api/v1/queues/XXXXXX"
            #         ]
            #     }
            # },
            # {
            #     "field.document_id.string": {
            #         "$emptyOrMissing": False
            #     }
            # },
            {
                "status": {
                    "$in": [
                        "confirmed",
                        "exported",
                        "to_review"
                    ]
                }
            }
        ]
    }
}
field_id = ['item_description']
annotations_collection = await process_annotations(client, token_input, url_input, query, field_id, bool_toggle, dropdown)
# Out:
# Cached https://levchenko.rossum.app/api/v1/annotations/search
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFsyNzk1MzldLCAicmV2ZXJzZWQiOiBmYWxzZX0%3D%3AUJBTkbO8LIcjjuruckihRSmUtnAr_V6YDI0MfJ3kc3s
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFs2NDA0NDZdLCAicmV2ZXJzZWQiOiBmYWxzZX0%3D%3AJTrOqIsy83-WNYfL8A8LZm0NuW8Dyy1yRBTWgGSCwio
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFs2NDA0ODFdLCAicmV2ZXJzZWQiOiBmYWxzZX0%3D%3A4x61fSdhrWHzXvE2QeASYHiZx7xl8BfwfY_sLBTfIO4
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFs2NDA1MDJdLCAicmV2ZXJzZWQiOiBmYWxzZX0%3D%3ARluG8yptLvzpSj8btbp2q8eQwzE-qBlxHLkUXgOa8K8
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFs2NDA1MjZdLCAicmV2ZXJzZWQiOiBmYWxzZX0%3D%3AVcXFiPsct8vEy5hYZQ1BpBmcPLv5dm6ynSnwvkP0hKE
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFs4MzMyNTNdLCAicmV2ZXJzZWQiOiBmYWxzZX0%3D%3A9OYq42TPAK16hZi6pYIePTYoa7ZEPV9wRtDDuOYiEN8
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFsxMjgyMDQ3XSwgInJldmVyc2VkIjogZmFsc2V9%3AmmEKtGpSB-DDub6O6efyZIUoUWBz5TPOr7i9Alk6fJk
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFsxMzAxMjI0XSwgInJldmVyc2VkIjogZmFsc2V9%3Am7BxEhyAUmpiUsMALROIS_JnyZ7DaboTaLqPtoPI0OI
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFsxMzc2MjEyXSwgInJldmVyc2VkIjogZmFsc2V9%3A5Has1rrUwg7aVDeQ1FxjOWUPD1_gXNj4Npro3PLxrXU
# Cached https://levchenko.rossum.app/api/v1/annotations/search?search_after=eyJxdWVyeV9oYXNoIjogIjAwNjg5ZmFmMmViM2Y5Nzk0MjkwYmM1Y2Q3YTI2MDI2IiwgInNlYXJjaF9hZnRlciI6IFsxNzE3ODg0XSwgInJldmVyc2VkIjogZmFsc2V9%3Aa509Y65y7zSLGhO_4vX2_4ASyTGGRCNI1T-X8ZNAOG0
# Cached https://levchenko.rossum.app/api/v1/annotations/279516/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279517/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279518/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279519/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279520/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279521/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279522/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279523/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279525/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279526/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279527/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279529/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279530/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279532/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279533/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279534/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279535/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279537/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279538/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279539/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279542/content
# Cached https://levchenko.rossum.app/api/v1/annotations/279543/content
# Cached https://levchenko.rossum.app/api/v1/annotations/417226/content
# Cached https://levchenko.rossum.app/api/v1/annotations/417227/content
# Cached https://levchenko.rossum.app/api/v1/annotations/417228/content
# Cached https://levchenko.rossum.app/api/v1/annotations/417229/content
# Cached https://levchenko.rossum.app/api/v1/annotations/491335/content
# Cached https://levchenko.rossum.app/api/v1/annotations/491455/content
# Cached https://levchenko.rossum.app/api/v1/annotations/494405/content
# Cached https://levchenko.rossum.app/api/v1/annotations/494406/content
# Cached https://levchenko.rossum.app/api/v1/annotations/494408/content
# Cached https://levchenko.rossum.app/api/v1/annotations/494409/content
# Cached https://levchenko.rossum.app/api/v1/annotations/529391/content
# Cached https://levchenko.rossum.app/api/v1/annotations/623733/content
# Cached https://levchenko.rossum.app/api/v1/annotations/631007/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640442/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640443/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640444/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640445/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640446/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640447/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640448/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640452/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640453/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640454/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640455/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640456/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640457/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640458/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640459/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640460/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640461/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640462/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640471/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640472/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640473/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640474/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640475/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640480/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640481/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640482/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640484/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640485/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640486/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640487/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640488/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640489/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640490/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640491/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640492/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640493/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640494/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640495/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640496/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640497/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640498/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640499/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640500/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640501/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640502/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640503/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640504/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640505/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640506/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640507/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640508/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640509/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640510/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640511/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640515/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640516/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640517/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640518/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640519/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640520/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640521/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640522/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640524/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640525/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640526/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640536/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640537/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640538/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640539/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640541/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640542/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640543/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640544/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640545/content
# Cached https://levchenko.rossum.app/api/v1/annotations/640546/content
# Cached https://levchenko.rossum.app/api/v1/annotations/690067/content
# Cached https://levchenko.rossum.app/api/v1/annotations/710231/content
# Cached https://levchenko.rossum.app/api/v1/annotations/769594/content
# Cached https://levchenko.rossum.app/api/v1/annotations/795577/content
# Cached https://levchenko.rossum.app/api/v1/annotations/803098/content
# Cached https://levchenko.rossum.app/api/v1/annotations/815667/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833165/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833251/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833252/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833253/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833255/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833256/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833257/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833519/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833520/content
# Cached https://levchenko.rossum.app/api/v1/annotations/833521/content
# Cached https://levchenko.rossum.app/api/v1/annotations/897232/content
# Cached https://levchenko.rossum.app/api/v1/annotations/923245/content
# Cached https://levchenko.rossum.app/api/v1/annotations/923246/content
# Cached https://levchenko.rossum.app/api/v1/annotations/923247/content
# Cached https://levchenko.rossum.app/api/v1/annotations/961675/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1135038/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1135039/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1135052/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1135053/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1209785/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1209820/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1281698/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1282046/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1282047/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1282048/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1284973/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1285038/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1285040/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1292152/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1292153/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1298371/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301212/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301213/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301214/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301215/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301216/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301217/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301218/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301219/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301220/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301221/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301222/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301223/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301224/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301225/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301226/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301227/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301228/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301229/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301230/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1301231/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1363338/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1363569/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1363570/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1374979/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376138/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376139/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376140/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376177/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376180/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376183/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376210/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376211/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1376212/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1391465/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1392383/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408364/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408365/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408366/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408367/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408368/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408369/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408370/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408373/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1408374/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1471849/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1519366/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1537401/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1555319/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1568316/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1568317/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1572678/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1572679/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1717884/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1725017/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1725019/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1725020/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1751760/content
# Cached https://levchenko.rossum.app/api/v1/annotations/1950769/content
# Cached https://levchenko.rossum.app/api/v1/annotations/2015963/content
# Cached https://levchenko.rossum.app/api/v1/annotations/2112764/content
# Cached https://levchenko.rossum.app/api/v1/annotations/2141002/content
# Cached https://levchenko.rossum.app/api/v1/annotations/2197083/content
# Cached https://levchenko.rossum.app/api/v1/annotations/2198451/content
# Cached https://levchenko.rossum.app/api/v1/annotations/2283432/content

# %%
for i,y in annotations_collection.items():
    print(i,y.get_positions("item_description"))
# Out:
# 279516 [[306.0, 726.0, 443.0, 755.0], [306.0, 792.0, 443.0, 815.0], [306.0, 846.0, 443.0, 875.0]]
# 279517 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0]]
# 279518 [[404.0, 588.0, 617.0, 611.0]]
# 279519 [[198.0, 1099.0, 449.0, 1145.0], [198.0, 1169.0, 449.0, 1193.0]]
# 279520 [[444.0, 1026.0, 576.0, 1055.0]]
# 279521 []
# 279522 [[264, 816, 393, 872], [264, 936, 396, 975], [264, 996, 442, 1057], [264, 1074, 402, 1121], [264, 1134, 454, 1205], [264, 1224, 455, 1257]]
# 279523 [[332.0, 746.0, 719.0, 793.0], [332.0, 794.0, 719.0, 841.0], [332.0, 842.0, 719.0, 889.0], [332.0, 890.0, 719.0, 937.0], [331.0, 938.0, 719.0, 985.0], [332.0, 986.0, 719.0, 1039.0], [332.0, 1040.0, 719.0, 1081.0], [331.0, 1082.0, 719.0, 1134.0], [332.0, 1134.0, 719.0, 1182.0], [332.0, 1182.0, 719.0, 1231.0], [332.0, 1232.0, 719.0, 1279.0], [332.0, 1280.0, 719.0, 1327.0], [332.0, 1328.0, 719.0, 1375.0], [332.0, 1376.0, 719.0, 1423.0], [332.0, 1424.0, 719.0, 1471.0], [332.0, 1472.0, 719.0, 1523.0], [332.0, 1530.0, 719.0, 1547.0], [324.0, 170.0, 665.0, 223.0], [324.0, 224.0, 665.0, 277.0], [324.0, 278.0, 665.0, 330.0], [324.0, 331.0, 665.0, 391.0], [324.0, 392.0, 665.0, 445.0], [324.0, 446.0, 665.0, 503.0]]
# 279525 [[174, 710, 455, 759], [174, 759, 455, 798], [174, 798, 455, 833], [174, 833, 455, 876], [174, 876, 455, 915], [174, 915, 455, 954], [174, 954, 455, 993]]
# 279526 [[330.0, 774.0, 606.0, 803.0]]
# 279527 [[474.0, 607.0, 695.0, 629.0]]
# 279529 []
# 279530 [[114.0, 1080.0, 647.0, 1118.0]]
# 279532 [[348.0, 684.0, 642.0, 746.0], [348.0, 745.0, 642.0, 823.0], [348.0, 828.0, 642.0, 866.0]]
# 279533 [[288.0, 930.0, 419.0, 960.0], [288.0, 972.0, 419.0, 1001.0], [288.0, 1020.0, 419.0, 1043.0]]
# 279534 [[258.0, 576.0, 419.0, 605.0]]
# 279535 [[336.0, 882.0, 527.0, 911.0], [336.0, 936.0, 527.0, 959.0], [336.0, 984.0, 527.0, 1011.0], [336.0, 1032.0, 527.0, 1061.0]]
# 279537 [[132.0, 930.0, 479.0, 967.0], [132.0, 972.0, 479.0, 1009.0], [132.0, 1020.0, 479.0, 1050.0], [132.0, 1062.0, 479.0, 1092.0], [132.0, 1104.0, 479.0, 1134.0], [132.0, 1146.0, 479.0, 1175.0]]
# 279538 [[252.0, 925.0, 443.0, 959.0], [252.0, 984.0, 443.0, 1013.0]]
# 279539 [[438.0, 674.0, 905.0, 721.0], [438.0, 722.0, 906.0, 787.0], [438.0, 788.0, 905.0, 815.0]]
# 279542 [[192.0, 810.0, 551.0, 841.0], [192.0, 848.0, 551.0, 883.0], [192.0, 888.0, 551.0, 917.0], [192.0, 930.0, 551.0, 959.0]]
# 279543 [[270.0, 1008.0, 509.0, 1031.0], [270.0, 1056.0, 509.0, 1079.0], [270.0, 1104.0, 509.0, 1128.0], [270.0, 1152.0, 509.0, 1181.0], [270.0, 1206.0, 509.0, 1229.0], [270.0, 1254.0, 509.0, 1277.0], [270.0, 1308.0, 509.0, 1331.0]]
# 417226 [[404.0, 588.0, 617.0, 611.0]]
# 417227 [[468.0, 367.0, 605.0, 389.0], None, None, None, None, None, None]
# 417228 [[444.0, 1026.0, 576.0, 1055.0]]
# 417229 [[84.0, 762.0, 455.0, 792.0], [84.0, 834.0, 456.0, 890.0], None]
# 491335 [[120.0, 908.0, 611.0, 942.0], [120.0, 954.0, 611.0, 985.0], [120.0, 996.0, 611.0, 1025.0]]
# 491455 [[120.0, 822.0, 611.0, 859.0], [120.0, 864.0, 611.0, 901.0], [120.0, 906.0, 611.0, 941.0]]
# 494405 []
# 494406 [[90.0, 540.0, 263.0, 571.0], [90.0, 572.0, 263.0, 599.0]]
# 494408 [[138.0, 588.0, 347.0, 613.0], [138.0, 614.0, 347.0, 641.0]]
# 494409 [[132.0, 577.0, 690.0, 608.0]]
# 529391 [None]
# 623733 [[138.0, 588.0, 347.0, 613.0], [138.0, 614.0, 347.0, 641.0]]
# 631007 [[444.0, 1026.0, 576.0, 1055.0]]
# 640442 [[244, 673, 846, 1197]]
# 640443 [None]
# 640444 [None]
# 640445 [[241.0, 674.0, 455.0, 725.0]]
# 640446 [[241.0, 673.0, 457.0, 743.0], [241.0, 896.0, 463.0, 939.0]]
# 640447 [[241.0, 674.0, 456.0, 749.0]]
# 640448 [[246.0, 674.0, 462.0, 743.0]]
# 640452 [[228.0, 726.0, 491.0, 773.0]]
# 640453 [[228.0, 726.0, 461.0, 773.0]]
# 640454 [[228.0, 726.0, 521.0, 773.0], [228.0, 798.0, 521.0, 825.0]]
# 640455 [[228.0, 726.0, 521.0, 773.0], [228.0, 798.0, 521.0, 825.0]]
# 640456 [[228.0, 726.0, 521.0, 773.0]]
# 640457 [[228.0, 726.0, 504.0, 773.0]]
# 640458 [[228.0, 726.0, 468.0, 773.0]]
# 640459 [[228.0, 726.0, 468.0, 773.0]]
# 640460 [[228.0, 726.0, 468.0, 773.0]]
# 640461 [[228.0, 726.0, 491.0, 773.0]]
# 640462 [[228.0, 726.0, 461.0, 767.0]]
# 640471 [[228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 900.0], [228.0, 901.0, 539.0, 960.0], [228.0, 961.0, 539.0, 1002.0], [228.0, 1003.0, 539.0, 1020.0], [228.0, 1021.0, 539.0, 1080.0], [228.0, 1081.0, 539.0, 1122.0], [228.0, 1123.0, 539.0, 1140.0], None, [228.0, 1165.0, 539.0, 1182.0], [228.0, 1182.0, 539.0, 1242.0], [228.0, 1242.0, 539.0, 1283.0], [222.0, 792.0, 539.0, 810.0], [222.0, 811.0, 539.0, 828.0], None, [222.0, 853.0, 539.0, 870.0], [222.0, 870.0, 539.0, 930.0], [222.0, 930.0, 539.0, 1002.0], [222.0, 1003.0, 539.0, 1044.0], [222.0, 1044.0, 539.0, 1116.0], [222.0, 1117.0, 539.0, 1176.0], [222.0, 1177.0, 539.0, 1236.0], [222.0, 1237.0, 539.0, 1283.0], [222.0, 792.0, 539.0, 846.0], [222.0, 847.0, 539.0, 864.0], [222.0, 865.0, 539.0, 925.0], [222.0, 926.0, 539.0, 966.0], [222.0, 967.0, 539.0, 984.0], None, [222.0, 1009.0, 539.0, 1026.0], [222.0, 1026.0, 539.0, 1104.0], [222.0, 1105.0, 539.0, 1223.0]]
# 640472 [[228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 900.0], [228.0, 901.0, 539.0, 960.0], [228.0, 961.0, 539.0, 1020.0], [228.0, 1021.0, 539.0, 1081.0], [228.0, 1082.0, 539.0, 1122.0], [228.0, 1123.0, 539.0, 1140.0], None, [228.0, 1165.0, 539.0, 1182.0], [228.0, 1182.0, 539.0, 1242.0], [228.0, 1242.0, 539.0, 1283.0], [222.0, 792.0, 539.0, 810.0], [222.0, 811.0, 539.0, 828.0], None, [222.0, 853.0, 539.0, 870.0], [222.0, 870.0, 539.0, 1002.0], [222.0, 1003.0, 539.0, 1044.0], [222.0, 1045.0, 539.0, 1056.0], [222.0, 1057.0, 539.0, 1116.0], [222.0, 1117.0, 539.0, 1176.0], [222.0, 1177.0, 539.0, 1236.0], [222.0, 1237.0, 539.0, 1283.0], [228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 864.0], [228.0, 865.0, 539.0, 925.0], [228.0, 926.0, 539.0, 966.0], [228.0, 966.0, 539.0, 1026.0], [228.0, 1027.0, 539.0, 1044.0], [228.0, 1045.0, 539.0, 1104.0], [228.0, 1105.0, 539.0, 1283.0], [228.0, 792.0, 539.0, 851.0]]
# 640473 [[228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 900.0], [228.0, 901.0, 539.0, 960.0], [228.0, 961.0, 539.0, 1020.0], [228.0, 1021.0, 539.0, 1080.0], [228.0, 1081.0, 539.0, 1122.0], [228.0, 1123.0, 539.0, 1140.0], None, [228.0, 1165.0, 539.0, 1182.0], [228.0, 1182.0, 539.0, 1242.0], [228.0, 1242.0, 539.0, 1283.0], [222.0, 792.0, 539.0, 810.0], [222.0, 811.0, 539.0, 828.0], None, [222.0, 853.0, 539.0, 870.0], [222.0, 870.0, 539.0, 1002.0], [222.0, 1003.0, 539.0, 1116.0], [222.0, 1117.0, 539.0, 1176.0], [222.0, 1177.0, 539.0, 1236.0], [222.0, 1237.0, 539.0, 1283.0], [222.0, 792.0, 539.0, 865.0], [222.0, 866.0, 539.0, 925.0], [222.0, 926.0, 539.0, 966.0], [222.0, 967.0, 539.0, 984.0], [222.0, 985.0, 539.0, 1049.0]]
# 640474 [[228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 900.0], [228.0, 901.0, 539.0, 960.0], [228.0, 961.0, 539.0, 1020.0], [228.0, 1021.0, 539.0, 1081.0], [228.0, 1082.0, 539.0, 1122.0], [228.0, 1123.0, 539.0, 1140.0], [228.0, 1141.0, 539.0, 1182.0], [228.0, 1182.0, 539.0, 1242.0], [228.0, 1242.0, 539.0, 1283.0], [222.0, 787.0, 539.0, 810.0], [222.0, 811.0, 539.0, 828.0], [222.0, 829.0, 539.0, 870.0], [222.0, 870.0, 539.0, 1002.0], [222.0, 1003.0, 539.0, 1056.0], [222.0, 1057.0, 539.0, 1116.0], [222.0, 1117.0, 539.0, 1176.0], [222.0, 1177.0, 539.0, 1236.0], [222.0, 1237.0, 539.0, 1283.0], [228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 864.0], [228.0, 865.0, 539.0, 925.0], [228.0, 926.0, 539.0, 966.0], [228.0, 967.0, 539.0, 984.0], [228.0, 985.0, 539.0, 1026.0], [228.0, 1026.0, 539.0, 1104.0], [228.0, 1105.0, 539.0, 1283.0], [228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 900.0], [228.0, 901.0, 539.0, 971.0]]
# 640475 [[228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 900.0], [228.0, 901.0, 539.0, 960.0], [228.0, 961.0, 539.0, 1020.0], [228.0, 1021.0, 539.0, 1081.0], [228.0, 1082.0, 539.0, 1122.0], [228.0, 1123.0, 539.0, 1140.0], [228.0, 1141.0, 539.0, 1182.0], [228.0, 1182.0, 539.0, 1242.0], [228.0, 1242.0, 539.0, 1283.0], [222.0, 787.0, 539.0, 810.0], [222.0, 811.0, 539.0, 828.0], None, [222.0, 853.0, 539.0, 870.0], [222.0, 870.0, 539.0, 1002.0], [222.0, 1003.0, 539.0, 1044.0], [222.0, 1045.0, 539.0, 1056.0], [222.0, 1057.0, 539.0, 1116.0], [222.0, 1117.0, 539.0, 1236.0], [222.0, 1237.0, 539.0, 1283.0], [228.0, 792.0, 539.0, 846.0], [228.0, 847.0, 539.0, 864.0], [228.0, 865.0, 539.0, 925.0], [228.0, 926.0, 539.0, 966.0], [228.0, 967.0, 539.0, 984.0], [228.0, 985.0, 539.0, 1026.0], [228.0, 1026.0, 539.0, 1283.0], [222.0, 792.0, 539.0, 851.0]]
# 640480 [None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 926.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 948.0], None, [192.0, 974.0, 449.0, 990.0], [192.0, 990.0, 449.0, 1033.0], [192.0, 1034.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1159.0], [192.0, 1160.0, 449.0, 1194.0], [192.0, 1195.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 906.0], [192.0, 907.0, 449.0, 924.0], None, [192.0, 950.0, 449.0, 984.0], None, [192.0, 1010.0, 449.0, 1050.0], None, [192.0, 1075.0, 449.0, 1092.0], [192.0, 1093.0, 449.0, 1110.0], None, [192.0, 1135.0, 449.0, 1176.0], None, [192.0, 1202.0, 449.0, 1241.0], None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 925.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 948.0], None, [192.0, 973.0, 449.0, 1008.0], None, [192.0, 1034.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1134.0], None, [192.0, 1159.0, 449.0, 1176.0], [192.0, 1177.0, 449.0, 1194.0], None, [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 906.0], [192.0, 907.0, 449.0, 924.0], None, [192.0, 950.0, 449.0, 984.0], None, [192.0, 1010.0, 449.0, 1050.0], None, [192.0, 1076.0, 449.0, 1092.0], [192.0, 1093.0, 449.0, 1110.0], None, [192.0, 1135.0, 449.0, 1176.0], None, [192.0, 1200.0, 449.0, 1241.0], None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 925.0, 449.0, 966.0], None, [192.0, 991.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 948.0], None, [192.0, 973.0, 449.0, 1008.0], None, [192.0, 1034.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1134.0], None, [192.0, 1160.0, 449.0, 1176.0], [192.0, 1177.0, 449.0, 1194.0], None, [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 925.0], None, [192.0, 950.0, 449.0, 989.0]]
# 640481 [None, [192.0, 866.0, 449.0, 906.0], None, [192.0, 926.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 948.0], None, [192.0, 973.0, 449.0, 1008.0], None, [192.0, 1034.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1134.0], None, [192.0, 1160.0, 449.0, 1218.0], [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 906.0], [192.0, 907.0, 449.0, 924.0], None, [192.0, 950.0, 449.0, 984.0], None, [192.0, 1010.0, 449.0, 1050.0], None, [192.0, 1076.0, 449.0, 1110.0], None, [192.0, 1135.0, 449.0, 1176.0], None, [192.0, 1200.0, 449.0, 1241.0], None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 926.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 948.0], None, [192.0, 973.0, 449.0, 1008.0], None, [192.0, 1034.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1134.0], None, [192.0, 1160.0, 449.0, 1194.0], None, [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 906.0], [192.0, 907.0, 449.0, 924.0], None, [192.0, 950.0, 449.0, 984.0], None, [192.0, 1010.0, 449.0, 1050.0], None, [192.0, 1076.0, 449.0, 1110.0], None, [192.0, 1135.0, 449.0, 1176.0], None, [192.0, 1200.0, 449.0, 1241.0], None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 926.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 948.0], None, [192.0, 973.0, 449.0, 990.0], [192.0, 991.0, 449.0, 1008.0], None, [192.0, 1034.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1134.0], None, [192.0, 1160.0, 449.0, 1194.0], None, [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 929.0]]
# 640482 [None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 926.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 924.0], [192.0, 925.0, 449.0, 948.0], None, [192.0, 974.0, 449.0, 990.0], [192.0, 990.0, 449.0, 1033.0], [192.0, 1034.0, 449.0, 1093.0], [192.0, 1094.0, 449.0, 1158.0], [192.0, 1159.0, 449.0, 1176.0], [192.0, 1177.0, 449.0, 1218.0], [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 906.0], [192.0, 907.0, 449.0, 924.0], None, [192.0, 950.0, 449.0, 984.0], None, [192.0, 1010.0, 449.0, 1050.0], None, [192.0, 1076.0, 449.0, 1110.0], None, [192.0, 1135.0, 449.0, 1176.0], None, [192.0, 1200.0, 449.0, 1241.0], None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 925.0, 449.0, 966.0], None, [192.0, 992.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1177.0], [192.0, 1178.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 882.0], None, [192.0, 908.0, 449.0, 924.0], [192.0, 925.0, 449.0, 948.0], None, [192.0, 974.0, 449.0, 990.0], [192.0, 991.0, 449.0, 1008.0], None, [192.0, 1034.0, 449.0, 1068.0], None, [192.0, 1094.0, 449.0, 1159.0], [192.0, 1160.0, 449.0, 1176.0], [192.0, 1177.0, 449.0, 1218.0], [192.0, 1219.0, 449.0, 1241.0], [192.0, 843.0, 449.0, 888.0], [192.0, 889.0, 449.0, 906.0], [192.0, 907.0, 449.0, 924.0], None, [192.0, 950.0, 449.0, 984.0], None, [192.0, 1010.0, 449.0, 1050.0], None, [192.0, 1076.0, 449.0, 1092.0], [192.0, 1093.0, 449.0, 1110.0], None, [192.0, 1135.0, 449.0, 1176.0], None, [192.0, 1200.0, 449.0, 1241.0], None, [192.0, 866.0, 449.0, 900.0], None, [192.0, 926.0, 449.0, 966.0], None, [192.0, 991.0, 449.0, 1008.0], [192.0, 1009.0, 449.0, 1050.0], [192.0, 1051.0, 449.0, 1092.0], None, [192.0, 1118.0, 449.0, 1134.0], [192.0, 1135.0, 449.0, 1176.0], [192.0, 1177.0, 449.0, 1241.0], [192.0, 840.0, 449.0, 883.0], None, [192.0, 908.0, 449.0, 947.0]]
# 640484 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 953.0]]
# 640485 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 905.0]]
# 640486 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 942.0], None, [228.0, 956.0, 407.0, 989.0]]
# 640487 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 953.0]]
# 640488 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 833.0]]
# 640489 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 942.0], None, [228.0, 956.0, 407.0, 990.0], None, [228.0, 1004.0, 407.0, 1049.0]]
# 640490 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 905.0]]
# 640491 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 941.0]]
# 640492 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 953.0]]
# 640493 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 942.0], None, [228.0, 956.0, 407.0, 989.0]]
# 640494 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 905.0]]
# 640495 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 905.0]]
# 640496 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 942.0], None, [228.0, 956.0, 407.0, 1003.0], [228.0, 1004.0, 407.0, 1049.0]]
# 640497 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 942.0], None, [228.0, 956.0, 407.0, 989.0]]
# 640498 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 900.0], [228.0, 901.0, 407.0, 953.0]]
# 640499 [[228.0, 756.0, 407.0, 805.0], [228.0, 806.0, 407.0, 853.0], [228.0, 854.0, 407.0, 905.0]]
# 640500 [[301.0, 918.0, 569.0, 969.0]]
# 640501 [[300.0, 918.0, 468.0, 971.0]]
# 640502 [None]
# 640503 [[306.0, 900.0, 569.0, 953.0], [306.0, 1026.0, 569.0, 1055.0]]
# 640504 [[300.0, 900.0, 569.0, 953.0], [300.0, 1002.0, 569.0, 1031.0]]
# 640505 [[306.0, 900.0, 425.0, 951.0]]
# 640506 [[306.0, 900.0, 569.0, 953.0]]
# 640507 [[300.0, 900.0, 569.0, 953.0], [300.0, 1128.0, 569.0, 1155.0]]
# 640508 [[138.0, 522.0, 455.0, 557.0]]
# 640509 [[138.0, 522.0, 347.0, 573.0]]
# 640510 [[138.0, 522.0, 323.0, 573.0]]
# 640511 [[138.0, 522.0, 377.0, 570.0]]
# 640515 [[73.0, 775.0, 335.0, 797.0]]
# 640516 [[73.0, 775.0, 335.0, 797.0]]
# 640517 [[73.0, 775.0, 335.0, 797.0]]
# 640518 [[73.0, 775.0, 335.0, 797.0]]
# 640519 [[73.0, 775.0, 335.0, 797.0], [73.0, 864.0, 335.0, 887.0], [73.0, 956.0, 335.0, 983.0], [73.0, 1044.0, 335.0, 1073.0]]
# 640520 [[73.0, 775.0, 335.0, 797.0], [73.0, 864.0, 335.0, 887.0], [73.0, 955.0, 335.0, 983.0], [73.0, 1044.0, 335.0, 1073.0], [73.0, 1140.0, 335.0, 1163.0], [73.0, 1225.0, 335.0, 1253.0], [78.0, 302.0, 335.0, 329.0], [78.0, 396.0, 335.0, 419.0], [78.0, 481.0, 335.0, 509.0], [78.0, 576.0, 335.0, 599.0], [78.0, 661.0, 335.0, 689.0], [78.0, 756.0, 335.0, 779.0], [78.0, 846.0, 335.0, 869.0], [78.0, 936.0, 335.0, 959.0], [78.0, 1026.0, 335.0, 1049.0], [78.0, 1116.0, 335.0, 1143.0], [78.0, 1212.0, 335.0, 1235.0], [78.0, 1296.0, 335.0, 1325.0], [78.0, 330.0, 407.0, 359.0], [78.0, 421.0, 407.0, 449.0], [78.0, 516.0, 407.0, 539.0], [78.0, 601.0, 407.0, 629.0], [78.0, 696.0, 407.0, 719.0], [78.0, 786.0, 407.0, 809.0], [78.0, 876.0, 407.0, 899.0], [78.0, 966.0, 407.0, 989.0], [78.0, 1056.0, 407.0, 1085.0]]
# 640521 [[78.0, 769.0, 455.0, 797.0], [78.0, 859.0, 455.0, 893.0], [78.0, 948.0, 455.0, 989.0], [78.0, 1044.0, 455.0, 1073.0], [78.0, 1104.0, 462.0, 1131.0], [78.0, 1140.0, 455.0, 1163.0], [78.0, 1230.0, 455.0, 1253.0], [78.0, 302.0, 335.0, 329.0], [78.0, 391.0, 335.0, 419.0], [78.0, 481.0, 335.0, 509.0], [78.0, 576.0, 335.0, 599.0]]
# 640522 [[78.0, 775.0, 341.0, 797.0], [78.0, 864.0, 341.0, 887.0], [78.0, 955.0, 341.0, 983.0], [78.0, 1045.0, 341.0, 1073.0], [78.0, 1140.0, 341.0, 1163.0], [78.0, 1225.0, 341.0, 1253.0]]
# 640524 [[73.0, 775.0, 335.0, 797.0], [73.0, 864.0, 335.0, 887.0], [73.0, 955.0, 335.0, 983.0]]
# 640525 [[73.0, 775.0, 335.0, 797.0]]
# 640526 [[73.0, 775.0, 335.0, 797.0], [73.0, 864.0, 335.0, 887.0], [73.0, 955.0, 335.0, 983.0], [73.0, 1044.0, 335.0, 1073.0], [73.0, 1135.0, 335.0, 1163.0], [73.0, 1225.0, 335.0, 1253.0], [78.0, 302.0, 455.0, 329.0], [78.0, 396.0, 455.0, 419.0], [78.0, 481.0, 455.0, 509.0], [78.0, 576.0, 455.0, 599.0], [78.0, 661.0, 455.0, 717.0], [78.0, 756.0, 455.0, 779.0], [78.0, 846.0, 455.0, 869.0], [78.0, 936.0, 455.0, 959.0], [78.0, 1026.0, 455.0, 1055.0], [78.0, 1117.0, 455.0, 1145.0], [78.0, 1212.0, 455.0, 1235.0]]
# 640536 [[96.0, 630.0, 533.0, 678.0]]
# 640537 [[96.0, 626.0, 366.0, 675.0]]
# 640538 [[96.0, 630.0, 643.0, 653.0]]
# 640539 [[92.0, 630.0, 366.0, 678.0], [92.0, 684.0, 366.0, 709.0], [92.0, 710.0, 366.0, 761.0], [92.0, 768.0, 366.0, 787.0], [92.0, 792.0, 366.0, 840.0]]
# 640541 [[92.0, 630.0, 330.0, 679.0], [92.0, 684.0, 330.0, 739.0], [92.0, 740.0, 330.0, 793.0], [92.0, 794.0, 330.0, 849.0], [92.0, 853.0, 330.0, 907.0], [92.0, 908.0, 330.0, 961.0], [92.0, 962.0, 330.0, 1015.0], [92.0, 1016.0, 330.0, 1073.0]]
# 640542 [[93, 627, 366, 677]]
# 640543 [[96.0, 630.0, 330.0, 679.0], [96.0, 684.0, 330.0, 739.0], [96.0, 740.0, 330.0, 791.0]]
# 640544 []
# 640545 [[79.0, 856.0, 203.0, 887.0], [84.0, 948.0, 203.0, 989.0], [84.0, 1038.0, 203.0, 1061.0], [84.0, 1128.0, 203.0, 1151.0], [79.0, 1210.0, 203.0, 1241.0], [84.0, 1302.0, 203.0, 1331.0], [84.0, 1392.0, 203.0, 1413.0]]
# 640546 [[79.0, 856.0, 251.0, 887.0]]
# 690067 [[174.0, 720.0, 455.0, 757.0], [174.0, 762.0, 455.0, 792.0], [174.0, 804.0, 455.0, 828.0], [174.0, 840.0, 455.0, 870.0], [174.0, 882.0, 455.0, 913.0], [174.0, 918.0, 455.0, 948.0], [174.0, 960.0, 455.0, 989.0]]
# 710231 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0]]
# 769594 [[96.0, 828.0, 588.0, 857.0], [354.0, 912.0, 899.0, 983.0], None]
# 795577 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0]]
# 803098 [None]
# 815667 [[216.0, 686.0, 383.0, 709.0], [216.0, 710.0, 383.0, 733.0], [216.0, 738.0, 383.0, 761.0]]
# 833165 [[173.0, 686.0, 320.0, 709.0]]
# 833251 [[48.0, 714.0, 185.0, 737.0]]
# 833252 [[98.0, 678.0, 497.0, 703.0], [98.0, 709.0, 497.0, 739.0], [98.0, 745.0, 497.0, 775.0], [98.0, 784.0, 497.0, 809.0]]
# 833253 [[36.0, 642.0, 455.0, 687.0], [36.0, 690.0, 456.0, 735.0], [36.0, 738.0, 455.0, 761.0]]
# 833255 [[48.0, 714.0, 341.0, 737.0]]
# 833256 [[205.0, 734.0, 523.0, 775.0], [210.0, 776.0, 523.0, 799.0], [210.0, 800.0, 523.0, 833.0]]
# 833257 []
# 833519 [[180.0, 936.0, 605.0, 960.0], [180.0, 961.0, 605.0, 991.0], [180.0, 992.0, 605.0, 1019.0], [180.0, 1056.0, 605.0, 1085.0]]
# 833520 [[36.0, 642.0, 455.0, 687.0], [36.0, 690.0, 456.0, 735.0], [36.0, 738.0, 455.0, 761.0]]
# 833521 [[114.0, 750.0, 551.0, 821.0], [114.0, 882.0, 558.0, 971.0]]
# 897232 []
# 923245 [None, None, None, None]
# 923246 [None]
# 923247 [None, None, None, None]
# 961675 [[247.0, 217.0, 666.0, 240.0], [247.0, 241.0, 661.0, 265.0], [247.0, 270.0, 661.0, 293.0], [247.0, 342.0, 666.0, 361.0], [247.0, 362.0, 661.0, 390.0], [247.0, 396.0, 661.0, 411.0], [247.0, 438.0, 666.0, 457.0], [247.0, 458.0, 661.0, 487.0], [247.0, 492.0, 661.0, 510.0], [247.0, 558.0, 666.0, 583.0], [247.0, 588.0, 661.0, 612.0], [247.0, 613.0, 661.0, 635.0], [247.0, 654.0, 661.0, 679.0], [247.0, 680.0, 661.0, 709.0], [247.0, 710.0, 661.0, 731.0], [252.0, 228.0, 528.0, 253.0], [252.0, 258.0, 527.0, 281.0]]
# 1135038 [[72.0, 834.0, 401.0, 863.0], [72.0, 906.0, 401.0, 935.0], [72.0, 984.0, 401.0, 1013.0], [72.0, 1062.0, 401.0, 1091.0]]
# 1135039 []
# 1135052 [[72.0, 834.0, 401.0, 863.0], [72.0, 906.0, 401.0, 935.0], [72.0, 984.0, 401.0, 1013.0], [72.0, 1062.0, 401.0, 1091.0]]
# 1135053 [[48.0, 714.0, 341.0, 737.0]]
# 1209785 [[35, 640, 464, 688], [35, 688, 464, 736], [35, 736, 464, 769]]
# 1209820 []
# 1281698 [[72.0, 834.0, 401.0, 863.0], [72.0, 906.0, 401.0, 935.0], [72.0, 984.0, 401.0, 1013.0], [72.0, 1062.0, 401.0, 1091.0]]
# 1282046 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1282047 [[210.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 836.0]]
# 1282048 [[210.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 836.0]]
# 1284973 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1285038 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1285040 [[150.0, 816.0, 371.0, 847.0], [150.0, 852.0, 371.0, 875.0]]
# 1292152 [[180.0, 936.0, 605.0, 960.0], [180.0, 961.0, 605.0, 991.0], [180.0, 992.0, 605.0, 1019.0], [180.0, 1056.0, 605.0, 1085.0]]
# 1292153 []
# 1298371 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1301212 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1301213 [[60.0, 534.0, 473.0, 558.0], [60.0, 559.0, 473.0, 576.0], [60.0, 577.0, 473.0, 594.0], [58.0, 594.0, 473.0, 625.0], [60.0, 626.0, 473.0, 649.0], [59.0, 650.0, 473.0, 671.0]]
# 1301214 [[158.0, 840.0, 443.0, 863.0]]
# 1301215 [[205.0, 734.0, 523.0, 775.0], [210.0, 776.0, 523.0, 799.0], [210.0, 800.0, 523.0, 833.0]]
# 1301216 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1301217 [[60.0, 534.0, 473.0, 558.0], [60.0, 559.0, 473.0, 576.0], [60.0, 577.0, 473.0, 594.0], [58.0, 594.0, 473.0, 625.0], [60.0, 626.0, 473.0, 649.0], [59.0, 650.0, 473.0, 671.0]]
# 1301218 [[158.0, 840.0, 443.0, 863.0]]
# 1301219 [[205.0, 734.0, 523.0, 775.0], [210.0, 776.0, 523.0, 799.0], [210.0, 800.0, 523.0, 833.0]]
# 1301220 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1301221 [[60.0, 534.0, 473.0, 558.0], [60.0, 559.0, 473.0, 576.0], [60.0, 577.0, 473.0, 594.0], [58.0, 594.0, 473.0, 625.0], [60.0, 626.0, 473.0, 649.0], [59.0, 650.0, 473.0, 671.0]]
# 1301222 [[158.0, 840.0, 443.0, 863.0]]
# 1301223 [[205.0, 734.0, 523.0, 775.0], [210.0, 776.0, 523.0, 799.0], [210.0, 800.0, 523.0, 833.0]]
# 1301224 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1301225 []
# 1301226 [[158.0, 840.0, 443.0, 863.0]]
# 1301227 [[205.0, 734.0, 523.0, 775.0], [210.0, 776.0, 523.0, 799.0], [210.0, 800.0, 523.0, 833.0]]
# 1301228 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1301229 [[60.0, 534.0, 473.0, 558.0], [60.0, 559.0, 473.0, 576.0], [60.0, 577.0, 473.0, 594.0], [58.0, 594.0, 473.0, 625.0], [60.0, 626.0, 473.0, 649.0], [59.0, 650.0, 473.0, 671.0]]
# 1301230 [[158.0, 840.0, 443.0, 863.0]]
# 1301231 [[205.0, 734.0, 523.0, 775.0], [210.0, 776.0, 523.0, 799.0], [210.0, 800.0, 523.0, 833.0]]
# 1363338 [[150.0, 816.0, 371.0, 847.0], [150.0, 852.0, 371.0, 875.0]]
# 1363569 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1363570 [[205.0, 734.0, 515.0, 768.0], [210.0, 769.0, 515.0, 811.0], [210.0, 812.0, 515.0, 833.0]]
# 1374979 [[114.0, 1080.0, 647.0, 1118.0]]
# 1376138 [[336.0, 878.0, 527.0, 911.0], [336.0, 930.0, 527.0, 961.0], [336.0, 979.0, 527.0, 1010.0], [336.0, 1029.0, 527.0, 1061.0]]
# 1376139 [[474.0, 607.0, 695.0, 630.0]]
# 1376140 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0]]
# 1376177 [[336.0, 878.0, 527.0, 911.0], [336.0, 930.0, 527.0, 961.0], [336.0, 979.0, 527.0, 1010.0], [336.0, 1029.0, 527.0, 1061.0]]
# 1376180 [[474.0, 607.0, 695.0, 630.0]]
# 1376183 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0]]
# 1376210 [[336.0, 878.0, 527.0, 911.0], [336.0, 930.0, 527.0, 961.0], [336.0, 979.0, 527.0, 1010.0], [336.0, 1029.0, 527.0, 1061.0]]
# 1376211 [[474.0, 607.0, 695.0, 630.0]]
# 1376212 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0]]
# 1391465 [[248, 1047, 496, 1133]]
# 1392383 []
# 1408364 [[444.0, 1026.0, 576.0, 1055.0]]
# 1408365 [[84.0, 762.0, 455.0, 792.0], [84.0, 834.0, 456.0, 890.0], None]
# 1408366 [[444.0, 1026.0, 576.0, 1055.0]]
# 1408367 [[132.0, 930.0, 479.0, 967.0], [132.0, 972.0, 479.0, 1009.0], [132.0, 1020.0, 479.0, 1050.0], [132.0, 1062.0, 479.0, 1092.0], [132.0, 1104.0, 479.0, 1134.0], [132.0, 1146.0, 479.0, 1175.0]]
# 1408368 [[348.0, 684.0, 642.0, 746.0], [348.0, 745.0, 642.0, 823.0], [348.0, 828.0, 642.0, 866.0]]
# 1408369 [[174, 710, 455, 759], [174, 759, 455, 798], [174, 798, 455, 833], [174, 833, 455, 876], [174, 876, 455, 915], [174, 915, 455, 954], [174, 954, 455, 993]]
# 1408370 [[198.0, 1098.0, 449.0, 1145.0], [198.0, 1164.0, 449.0, 1193.0]]
# 1408373 [[150.0, 1285.0, 422.0, 1319.0], [270.0, 1051.0, 493.0, 1133.0]]
# 1408374 [[150.0, 1285.0, 422.0, 1319.0], [270.0, 1051.0, 493.0, 1133.0]]
# 1471849 [[204.0, 716.0, 473.0, 763.0], [204.0, 768.0, 473.0, 817.0], [204.0, 818.0, 473.0, 883.0], [204.0, 884.0, 473.0, 932.0], [204.0, 936.0, 473.0, 983.0]]
# 1519366 [[132.0, 626.0, 239.0, 653.0], [132.0, 666.0, 239.0, 695.0], [336.0, 876.0, 527.0, 911.0], [336.0, 930.0, 527.0, 960.0], [336.0, 979.0, 527.0, 1010.0], [336.0, 1029.0, 527.0, 1061.0]]
# 1537401 [[396.0, 614.0, 707.0, 637.0], [396.0, 638.0, 707.0, 655.0], [396.0, 656.0, 707.0, 673.0], [396.0, 674.0, 707.0, 691.0], [396.0, 692.0, 707.0, 709.0], [396.0, 710.0, 707.0, 734.0], [396.0, 733.0, 707.0, 752.0], [396.0, 752.0, 707.0, 770.0], [396.0, 770.0, 707.0, 787.0], [396.0, 788.0, 707.0, 805.0], [396.0, 806.0, 707.0, 829.0], [396.0, 830.0, 707.0, 847.0], [396.0, 847.0, 707.0, 866.0], [396.0, 866.0, 707.0, 884.0], [396.0, 884.0, 707.0, 901.0], [396.0, 902.0, 707.0, 919.0], [396.0, 920.0, 707.0, 947.0]]
# 1555319 [[108.0, 636.0, 413.0, 661.0], [108.0, 698.0, 413.0, 727.0], [108.0, 728.0, 413.0, 759.0]]
# 1568316 [[300.0, 302.0, 713.0, 325.0], [300.0, 326.0, 713.0, 349.0], [300.0, 350.0, 713.0, 373.0], [300.0, 374.0, 713.0, 397.0], [300.0, 398.0, 713.0, 421.0], [300.0, 422.0, 713.0, 445.0], [300.0, 446.0, 713.0, 469.0], [300.0, 470.0, 713.0, 493.0], [300.0, 498.0, 713.0, 517.0], [300.0, 522.0, 713.0, 541.0], [300.0, 546.0, 713.0, 565.0], [300.0, 570.0, 713.0, 589.0], [300.0, 594.0, 713.0, 613.0], [300.0, 618.0, 713.0, 637.0], [300.0, 638.0, 713.0, 661.0], [300.0, 667.0, 713.0, 685.0], [300.0, 686.0, 713.0, 709.0], [300.0, 710.0, 713.0, 739.0], [300.0, 740.0, 713.0, 763.0], [300.0, 764.0, 713.0, 787.0], [300.0, 788.0, 713.0, 811.0], [300.0, 812.0, 713.0, 833.0]]
# 1568317 [[301.0, 80.0, 719.0, 103.0], [301.0, 104.0, 719.0, 127.0], [301.0, 128.0, 719.0, 151.0], [301.0, 152.0, 719.0, 175.0], [301.0, 176.0, 719.0, 199.0], [301.0, 200.0, 719.0, 223.0], [301.0, 224.0, 719.0, 247.0], [301.0, 248.0, 719.0, 271.0], [301.0, 276.0, 719.0, 295.0], [301.0, 300.0, 719.0, 319.0], [301.0, 324.0, 719.0, 343.0], [301.0, 348.0, 719.0, 367.0], [301.0, 372.0, 719.0, 391.0], [301.0, 396.0, 719.0, 415.0], [301.0, 420.0, 719.0, 439.0], [301.0, 445.0, 719.0, 467.0]]
# 1572678 [[74.0, 836.0, 395.0, 861.0], [74.0, 914.0, 365.0, 933.0], [74.0, 990.0, 335.0, 1013.0], [74.0, 1066.0, 140.0, 1090.0]]
# 1572679 []
# 1717884 [[42.0, 804.0, 671.0, 834.0], [42.0, 846.0, 671.0, 875.0], [42.0, 894.0, 671.0, 925.0], [42.0, 936.0, 671.0, 995.0], [42.0, 1008.0, 671.0, 1045.0], [42.0, 1056.0, 671.0, 1085.0], [42.0, 1098.0, 671.0, 1135.0], [42.0, 1141.0, 671.0, 1203.0], [42.0, 1218.0, 671.0, 1255.0], [42.0, 1261.0, 671.0, 1325.0]]
# 1725017 []
# 1725019 []
# 1725020 []
# 1751760 [[78.0, 678.0, 480.0, 732.0], [78.0, 744.0, 480.0, 816.0], [78.0, 828.0, 480.0, 876.0], [78.0, 888.0, 480.0, 942.0], [78.0, 948.0, 480.0, 990.0], [78.0, 1014.0, 480.0, 1068.0], [78.0, 1074.0, 480.0, 1128.0], [78.0, 1140.0, 480.0, 1163.0]]
# 1950769 []
# 2015963 [[154.0, 1289.0, 418.0, 1314.0], [280.0, 1056.0, 488.0, 1130.0]]
# 2112764 [[332.0, 746.0, 719.0, 793.0], [332.0, 794.0, 719.0, 841.0], [332.0, 842.0, 719.0, 889.0], [332.0, 890.0, 719.0, 937.0], [332.0, 938.0, 719.0, 985.0], [332.0, 986.0, 719.0, 1039.0], [332.0, 1040.0, 719.0, 1081.0], [332.0, 1082.0, 719.0, 1134.0], [332.0, 1135.0, 719.0, 1182.0], [332.0, 1183.0, 719.0, 1231.0], [332.0, 1232.0, 719.0, 1279.0], [332.0, 1280.0, 719.0, 1327.0], [332.0, 1328.0, 719.0, 1375.0], [332.0, 1376.0, 719.0, 1423.0], [332.0, 1424.0, 719.0, 1471.0], [332.0, 1472.0, 719.0, 1523.0], [332.0, 1530.0, 719.0, 1547.0], [324.0, 170.0, 665.0, 223.0], [324.0, 224.0, 665.0, 277.0], [324.0, 278.0, 665.0, 330.0], [324.0, 331.0, 665.0, 391.0], [324.0, 391.0, 671.0, 445.0], [324.0, 446.0, 665.0, 503.0]]
# 2141002 [[274.0, 637.0, 521.0, 683.0], [274.0, 740.0, 521.0, 786.0], [274.0, 843.0, 521.0, 888.0], [274.0, 945.0, 521.0, 991.0], [274.0, 1048.0, 521.0, 1094.0], [274.0, 1151.0, 464.0, 1196.0], [274.0, 1253.0, 464.0, 1299.0], [274.0, 1356.0, 521.0, 1402.0], [407.0, 1483.0, 521.0, 1505.0], [274.0, 1561.0, 651.0, 1607.0], None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# 2197083 []
# 2198451 []
# 2283432 [[207.0, 866.0, 460.0, 881.0], [207.0, 898.0, 449.0, 913.0]]

# %%
# Out:
# {'id': 118391551, 'category': 'datapoint', 'schema_id': 'item_description', 'time_spent': 0.0, 'time_spent_overall': 0.0, 'validation_sources': [], 'content': {'value': 'Sendvičovač ETA Sorento 3151 90010\nčerný/nerez', 'page': 1, 'position': [205.0, 734.0, 515.0, 768.0], 'rir_text': 'Sendvičovač ETA Sorento 3151 90010\nčerný/nerez', 'rir_raw_text': 'Sendvičovač ETA Sorento 3151 90010\nčerný/nerez', 'ocr_text': None, 'ocr_raw_text': None, 'rir_page': 1, 'rir_position': [205.0, 734.0, 515.0, 768.0], 'ocr_position': None, 'rir_confidence': 0.7973150204943078, 'connector_position': None, 'connector_text': None, 'normalized_value': None}, 'url': 'https://levchenko.rossum.app/api/v1/annotations/1298371/content/118391551'}
# {'id': 118391563, 'category': 'datapoint', 'schema_id': 'item_description', 'time_spent': 0.0, 'time_spent_overall': 0.0, 'validation_sources': [], 'content': {'value': 'Recyklační příspěvek 2-11 (malá bílá - aku\nvysavače)', 'page': 1, 'position': [210.0, 769.0, 515.0, 811.0], 'rir_text': 'Recyklační příspěvek 2-11 (malá bílá - aku\nvysavače)', 'rir_raw_text': 'Recyklační příspěvek 2-11 (malá bílá - aku\nvysavače)', 'ocr_text': None, 'ocr_raw_text': None, 'rir_page': 1, 'rir_position': [210.0, 769.0, 515.0, 811.0], 'ocr_position': None, 'rir_confidence': 0.7965039817910873, 'connector_position': None, 'connector_text': None, 'normalized_value': None}, 'url': 'https://levchenko.rossum.app/api/v1/annotations/1298371/content/118391563'}
# {'id': 118391575, 'category': 'datapoint', 'schema_id': 'item_description', 'time_spent': 0.0, 'time_spent_overall': 0.0, 'validation_sources': [], 'content': {'value': 'Odvápňovač DeLonghi EcoDecalk /DLSC500', 'page': 1, 'position': [210.0, 812.0, 515.0, 833.0], 'rir_text': 'Odvápňovač DeLonghi EcoDecalk /DLSC500', 'rir_raw_text': 'Odvápňovač DeLonghi EcoDecalk /DLSC500', 'ocr_text': None, 'ocr_raw_text': None, 'rir_page': 1, 'rir_position': [210.0, 812.0, 515.0, 833.0], 'ocr_position': None, 'rir_confidence': 0.7204879323630197, 'connector_position': None, 'connector_text': None, 'normalized_value': None}, 'url': 'https://levchenko.rossum.app/api/v1/annotations/1298371/content/118391575'}
